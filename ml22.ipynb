# %%
import matplotlib.pyplot as plt
activites=["eat","sleep","work","play"]
slices=[4,10,3,1]
colors=['red','m','green','blue']
plt.pie(slices,labels=activites,colors=colors,shadow=True,startangle=360,autopct="%1.1f%%"
        ,explode=(0,0.05,0,0))
plt.legend()
plt.show()
