# %%
import matplotlib.pyplot as plt
import numpy as np
t=np.arange(0.0,2.0,0.01)
s=1+np.cos(2*np.pi*t)
plt.plot(t,s,"--")
plt.grid()
plt.xlabel('Time(t)')
plt.ylabel('voltages(mV)')
plt.title("cos wave plot(cos(x))")
plt.show()

# %%
print(1+m.cos(2*3.14*0.0))
# Out:
# 2.0
